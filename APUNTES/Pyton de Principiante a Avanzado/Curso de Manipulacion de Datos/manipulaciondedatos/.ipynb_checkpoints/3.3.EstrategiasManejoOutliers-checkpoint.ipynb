# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import HuberRegressor

# %%
df = pd.read_csv('VeinteDatos.csv')
df.loc[df['ID'] == 1, 'Salario'] = 5000
df.loc[df['ID'] == 2, 'Salario'] = 6000
df.loc[df['ID'] == 6, 'Edad'] = 25
df.loc[df['ID'] == 17, 'Edad'] = 32
df.fillna({'Salario': df['Salario'].mean()}, inplace=True)
display(df)
# Out:
#     ID  Nombre  Edad       Salario Fecha_Ingreso
# 0    1     Ana  23.0   5000.000000    2020-01-10
# 1    2    Luis  35.0   6000.000000    2019-06-15
# 2    3  Carlos  30.0  55941.176471    2020-03-25
# 3    4   María  22.0  58000.000000           NaN
# 4    5   Elena  28.0  49000.000000    2018-07-30
# 5    6   Jorge  25.0  62000.000000    2017-09-14
# 6    7   Sofía  34.0  72000.000000    2016-11-22
# 7    8  Andrés  45.0  61000.000000    2021-04-01
# 8    9   Laura  29.0  52000.000000    2015-05-19
# 9   10   Pedro  41.0  67000.000000    2014-08-25
# 10  11   Paula  38.0  55000.000000    2013-12-30
# 11  12   Diego  25.0  53000.000000    2012-02-11
# 12  13  Carmen  33.0  55941.176471    2011-10-17
# 13  14   Marta  27.0  69000.000000           NaN
# 14  15     NaN  32.0  64000.000000    2020-09-09
# 15  16   Pablo  36.0  71000.000000    2018-04-05
# 16  17   Lucía  32.0  68000.000000    2019-11-22
# 17  18  Manuel  39.0  73000.000000    2010-07-27
# 18  19   Carla  31.0  55941.176471    2020-05-13
# 19  20   David  40.0  66000.000000    2017-01-29

# %%
#rangos intercuartilicos para indentificar datos atipicos
Q1 = df['Salario'].quantile(0.25)
Q3 = df['Salario'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#identificacion de datos atipicos
outliers = df[(df['Salario'] < lower_bound) | (df['Salario'] > upper_bound)]
display(outliers)
# Out:
#    ID Nombre  Edad  Salario Fecha_Ingreso
# 0   1    Ana  23.0   5000.0    2020-01-10
# 1   2   Luis  35.0   6000.0    2019-06-15

# %%
#eliminar outliers
df_cleaned = df[(df['Salario'] >= lower_bound) & (df['Salario'] <= upper_bound)]
display(df_cleaned)
# Out:
#     ID  Nombre  Edad       Salario Fecha_Ingreso
# 2    3  Carlos  30.0  55941.176471    2020-03-25
# 3    4   María  22.0  58000.000000           NaN
# 4    5   Elena  28.0  49000.000000    2018-07-30
# 5    6   Jorge  25.0  62000.000000    2017-09-14
# 6    7   Sofía  34.0  72000.000000    2016-11-22
# 7    8  Andrés  45.0  61000.000000    2021-04-01
# 8    9   Laura  29.0  52000.000000    2015-05-19
# 9   10   Pedro  41.0  67000.000000    2014-08-25
# 10  11   Paula  38.0  55000.000000    2013-12-30
# 11  12   Diego  25.0  53000.000000    2012-02-11
# 12  13  Carmen  33.0  55941.176471    2011-10-17
# 13  14   Marta  27.0  69000.000000           NaN
# 14  15     NaN  32.0  64000.000000    2020-09-09
# 15  16   Pablo  36.0  71000.000000    2018-04-05
# 16  17   Lucía  32.0  68000.000000    2019-11-22
# 17  18  Manuel  39.0  73000.000000    2010-07-27
# 18  19   Carla  31.0  55941.176471    2020-05-13
# 19  20   David  40.0  66000.000000    2017-01-29

# %%
#Transformacion de datos
#cada valor de salario le aplico el logaritmo
df['Salario_Log'] = np.log(df['Salario'])
display(df)
#se puede aplciar raiz cuadrada pero eso depende de como lo querramos manejar
#tendencia de estabilidad en el eje x, (asintota horizontal)
# Out:
#     ID  Nombre  Edad       Salario Fecha_Ingreso  Salario_Log
# 0    1     Ana  23.0   5000.000000    2020-01-10     8.517193
# 1    2    Luis  35.0   6000.000000    2019-06-15     8.699515
# 2    3  Carlos  30.0  55941.176471    2020-03-25    10.932056
# 3    4   María  22.0  58000.000000           NaN    10.968198
# 4    5   Elena  28.0  49000.000000    2018-07-30    10.799576
# 5    6   Jorge  25.0  62000.000000    2017-09-14    11.034890
# 6    7   Sofía  34.0  72000.000000    2016-11-22    11.184421
# 7    8  Andrés  45.0  61000.000000    2021-04-01    11.018629
# 8    9   Laura  29.0  52000.000000    2015-05-19    10.858999
# 9   10   Pedro  41.0  67000.000000    2014-08-25    11.112448
# 10  11   Paula  38.0  55000.000000    2013-12-30    10.915088
# 11  12   Diego  25.0  53000.000000    2012-02-11    10.878047
# 12  13  Carmen  33.0  55941.176471    2011-10-17    10.932056
# 13  14   Marta  27.0  69000.000000           NaN    11.141862
# 14  15     NaN  32.0  64000.000000    2020-09-09    11.066638
# 15  16   Pablo  36.0  71000.000000    2018-04-05    11.170435
# 16  17   Lucía  32.0  68000.000000    2019-11-22    11.127263
# 17  18  Manuel  39.0  73000.000000    2010-07-27    11.198215
# 18  19   Carla  31.0  55941.176471    2020-05-13    10.932056
# 19  20   David  40.0  66000.000000    2017-01-29    11.097410

# %%
#imputacion de valores atipicos
#significa cambiar valores de datos por valores medios o estadares para no verse perjudicado a los demas datos
#cambio por una mediana
df['Salario_Capped'] = np.where(
    (df['Salario'] < lower_bound) | (df['Salario'] > upper_bound),
    df['Salario'].mean(),
    df['Salario'] #que columna vamos a reemplazar
)
display(df)
# Out:
#     ID  Nombre  Edad       Salario Fecha_Ingreso  Salario_Log  Salario_Capped
# 0    1     Ana  23.0   5000.000000    2020-01-10     8.517193    55941.176471
# 1    2    Luis  35.0   6000.000000    2019-06-15     8.699515    55941.176471
# 2    3  Carlos  30.0  55941.176471    2020-03-25    10.932056    55941.176471
# 3    4   María  22.0  58000.000000           NaN    10.968198    58000.000000
# 4    5   Elena  28.0  49000.000000    2018-07-30    10.799576    49000.000000
# 5    6   Jorge  25.0  62000.000000    2017-09-14    11.034890    62000.000000
# 6    7   Sofía  34.0  72000.000000    2016-11-22    11.184421    72000.000000
# 7    8  Andrés  45.0  61000.000000    2021-04-01    11.018629    61000.000000
# 8    9   Laura  29.0  52000.000000    2015-05-19    10.858999    52000.000000
# 9   10   Pedro  41.0  67000.000000    2014-08-25    11.112448    67000.000000
# 10  11   Paula  38.0  55000.000000    2013-12-30    10.915088    55000.000000
# 11  12   Diego  25.0  53000.000000    2012-02-11    10.878047    53000.000000
# 12  13  Carmen  33.0  55941.176471    2011-10-17    10.932056    55941.176471
# 13  14   Marta  27.0  69000.000000           NaN    11.141862    69000.000000
# 14  15     NaN  32.0  64000.000000    2020-09-09    11.066638    64000.000000
# 15  16   Pablo  36.0  71000.000000    2018-04-05    11.170435    71000.000000
# 16  17   Lucía  32.0  68000.000000    2019-11-22    11.127263    68000.000000
# 17  18  Manuel  39.0  73000.000000    2010-07-27    11.198215    73000.000000
# 18  19   Carla  31.0  55941.176471    2020-05-13    10.932056    55941.176471
# 19  20   David  40.0  66000.000000    2017-01-29    11.097410    66000.000000

# %%
#binned
#agrupacion de intervalos par suavizar datos atipicos
df['Salario_Binned'] = pd.cut(df['Salario'], bins=5)
display(df)
# Out:
#     ID  Nombre  Edad       Salario Fecha_Ingreso  Salario_Log  Salario_Capped  \
# 0    1     Ana  23.0   5000.000000    2020-01-10     8.517193    55941.176471
# 1    2    Luis  35.0   6000.000000    2019-06-15     8.699515    55941.176471
# 2    3  Carlos  30.0  55941.176471    2020-03-25    10.932056    55941.176471
# 3    4   María  22.0  58000.000000           NaN    10.968198    58000.000000
# 4    5   Elena  28.0  49000.000000    2018-07-30    10.799576    49000.000000
# 5    6   Jorge  25.0  62000.000000    2017-09-14    11.034890    62000.000000
# 6    7   Sofía  34.0  72000.000000    2016-11-22    11.184421    72000.000000
# 7    8  Andrés  45.0  61000.000000    2021-04-01    11.018629    61000.000000
# 8    9   Laura  29.0  52000.000000    2015-05-19    10.858999    52000.000000
# 9   10   Pedro  41.0  67000.000000    2014-08-25    11.112448    67000.000000
# 10  11   Paula  38.0  55000.000000    2013-12-30    10.915088    55000.000000
# 11  12   Diego  25.0  53000.000000    2012-02-11    10.878047    53000.000000
# 12  13  Carmen  33.0  55941.176471    2011-10-17    10.932056    55941.176471
# 13  14   Marta  27.0  69000.000000           NaN    11.141862    69000.000000
# 14  15     NaN  32.0  64000.000000    2020-09-09    11.066638    64000.000000
# 15  16   Pablo  36.0  71000.000000    2018-04-05    11.170435    71000.000000
# 16  17   Lucía  32.0  68000.000000    2019-11-22    11.127263    68000.000000
# 17  18  Manuel  39.0  73000.000000    2010-07-27    11.198215    73000.000000
# 18  19   Carla  31.0  55941.176471    2020-05-13    10.932056    55941.176471
# 19  20   David  40.0  66000.000000    2017-01-29    11.097410    66000.000000
#
#         Salario_Binned
# 0    (4932.0, 18600.0]
# 1    (4932.0, 18600.0]
# 2   (45800.0, 59400.0]
# 3   (45800.0, 59400.0]
# 4   (45800.0, 59400.0]
# 5   (59400.0, 73000.0]
# 6   (59400.0, 73000.0]
# 7   (59400.0, 73000.0]
# 8   (45800.0, 59400.0]
# 9   (59400.0, 73000.0]
# 10  (45800.0, 59400.0]
# 11  (45800.0, 59400.0]
# 12  (45800.0, 59400.0]
# 13  (59400.0, 73000.0]
# 14  (59400.0, 73000.0]
# 15  (59400.0, 73000.0]
# 16  (59400.0, 73000.0]
# 17  (59400.0, 73000.0]
# 18  (45800.0, 59400.0]
# 19  (59400.0, 73000.0]

# %%
#uso de modelos robustos
#se ocupa sklearn
x = df[['Edad']]
y = df['Salario']

# %%
huber = HuberRegressor()
huber.fit(x,y)
y_pred = huber.predict(x)
print(y_pred)
# Out:
# [54472.32225396 61707.7430119  58692.98436276 53869.37052413
#  57487.0809031  55678.22571362 61104.79128207 67737.26031017
#  58090.03263293 65325.45339086 63516.59820138 55678.22571362
#  60501.83955224 56884.12917327 59898.88782241 62310.69474172
#  59898.88782241 64119.54993121 59295.93609258 64722.50166104]
