# %%
import pandas as pd
df = pd.read_csv('sales_data_correlated.csv')
df.head()
# Out:
#    Order ID             Product  Price Each  Order Date  \
# 0    176633       Flatscreen TV       13.69  2023-01-01
# 1    176592    Wired Headphones       13.28  2023-01-02
# 2    176655  Macbook Pro Laptop       14.27  2023-01-03
# 3    176586       Flatscreen TV       15.77  2023-01-04
# 4    176626        Google Phone       12.30  2023-01-05
#
#                  Purchase Address  Quantity Ordered
# 0        492 Main St, Phoenix, AZ                 4
# 1         910 Main St, Dallas, TX                 4
# 2       345 Main St, Portland, OR                 4
# 3    275 Main St, Los Angeles, CA                 3
# 4  138 Main St, San Francisco, CA                 4

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day
df['Day of Week'] = df['Order Date'].dt.day_name()
df['Hour'] = df['Order Date'].dt.hour
df.head()
# Out:
#    Order ID             Product  Price Each Order Date  \
# 0    176633       Flatscreen TV       13.69 2023-01-01
# 1    176592    Wired Headphones       13.28 2023-01-02
# 2    176655  Macbook Pro Laptop       14.27 2023-01-03
# 3    176586       Flatscreen TV       15.77 2023-01-04
# 4    176626        Google Phone       12.30 2023-01-05
#
#                  Purchase Address  Quantity Ordered  Year  Month  Day  \
# 0        492 Main St, Phoenix, AZ                 4  2023      1    1
# 1         910 Main St, Dallas, TX                 4  2023      1    2
# 2       345 Main St, Portland, OR                 4  2023      1    3
# 3    275 Main St, Los Angeles, CA                 3  2023      1    4
# 4  138 Main St, San Francisco, CA                 4  2023      1    5
#
#   Day of Week  Hour
# 0      Sunday     0
# 1      Monday     0
# 2     Tuesday     0
# 3   Wednesday     0
# 4    Thursday     0

# %%
df.set_index('Order Date', inplace=True)
df.head()
# Out:
#             Order ID             Product  Price Each  \
# Order Date
# 2023-01-01    176633       Flatscreen TV       13.69
# 2023-01-02    176592    Wired Headphones       13.28
# 2023-01-03    176655  Macbook Pro Laptop       14.27
# 2023-01-04    176586       Flatscreen TV       15.77
# 2023-01-05    176626        Google Phone       12.30
#
#                           Purchase Address  Quantity Ordered  Year  Month  \
# Order Date
# 2023-01-01        492 Main St, Phoenix, AZ                 4  2023      1
# 2023-01-02         910 Main St, Dallas, TX                 4  2023      1
# 2023-01-03       345 Main St, Portland, OR                 4  2023      1
# 2023-01-04    275 Main St, Los Angeles, CA                 3  2023      1
# 2023-01-05  138 Main St, San Francisco, CA                 4  2023      1
#
#             Day Day of Week  Hour
# Order Date
# 2023-01-01    1      Sunday     0
# 2023-01-02    2      Monday     0
# 2023-01-03    3     Tuesday     0
# 2023-01-04    4   Wednesday     0
# 2023-01-05    5    Thursday     0

# %%
monthly_sales = df['Quantity Ordered'].resample('ME').sum()
print(monthly_sales)
# Out:
# Order Date
# 2023-01-31    53
# 2023-02-28    10
# 2023-03-31     0
# 2023-04-30     0
# Freq: ME, Name: Quantity Ordered, dtype: int64

# %%
df['Days Since Last Order'] = df.index.to_series().diff().dt.days

# %%
df.head()
# Out:
#             Order ID             Product  Price Each  \
# Order Date
# 2023-01-01    176633       Flatscreen TV       13.69
# 2023-01-02    176592    Wired Headphones       13.28
# 2023-01-03    176655  Macbook Pro Laptop       14.27
# 2023-01-04    176586       Flatscreen TV       15.77
# 2023-01-05    176626        Google Phone       12.30
#
#                           Purchase Address  Quantity Ordered  Year  Month  \
# Order Date
# 2023-01-01        492 Main St, Phoenix, AZ                 4  2023      1
# 2023-01-02         910 Main St, Dallas, TX                 4  2023      1
# 2023-01-03       345 Main St, Portland, OR                 4  2023      1
# 2023-01-04    275 Main St, Los Angeles, CA                 3  2023      1
# 2023-01-05  138 Main St, San Francisco, CA                 4  2023      1
#
#             Day Day of Week  Hour  Days Since Last Order
# Order Date
# 2023-01-01    1      Sunday     0                    NaN
# 2023-01-02    2      Monday     0                    1.0
# 2023-01-03    3     Tuesday     0                    1.0
# 2023-01-04    4   Wednesday     0                    1.0
# 2023-01-05    5    Thursday     0                    1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 3))
monthly_sales.plot()
plt.title('Ventas Mensuales')
plt.xlabel('Fecha')
plt.ylabel('Cantidad Vendida')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(5, 3))

sns.lineplot(data=monthly_sales)

plt.title('Ventas Mensuales con Seaborn')
plt.xlabel('Fecha')
plt.ylabel('Cantidad Vendida')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from statsmodels.tsa.seasonal import seasonal_decompose
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
! pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from statsmodels) (2.0.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from statsmodels) (1.14.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /home/jorge/Programs/numpi-python/env/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 10.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.4
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(monthly_sales, model='additive', period=1)
decomposition.plot()
plt.show()

# %%
plt.figure(figsize=(6, 3))
df[df['Product'] == 'USB-C Charging Cable']['Quantity Ordered'].resample('ME').sum().plot(label='USB-C Cable')
df[df['Product'] == 'Google Phone']['Quantity Ordered'].resample('ME').sum().plot(label='Google Phone')
plt.title('Comparación de Ventas por Producto')
plt.xlabel('Fecha')
plt.ylabel('Cantidad Vendida')
plt.legend()
plt.show()
