# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo'],
    'Ventas': [200,300,400,500,600]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#        Mes  Ventas
# 0    Enero     200
# 1  Febrero     300
# 2    Marzo     400
# 3    Abril     500
# 4     Mayo     600

# %%
#grafico de barras
plt.figure(figsize=(10,6))
plt.bar(df['Mes'], df['Ventas'], color='skyblue')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.title('Ventas Mensuales')
plt.show()

# %%
#analisis de datos mas soficsticados
data = {
    'Empleado': ['Juan','Ana','Pedro','Luis','Maria'],
    'Departamento': ['Ventas','Marketing','Ventas','IT','Marketing'],
    'Salario': [50000,60000,55000,58000,62000],
    'Experiencia': [5,7,6,8,9]
}

df = pd.DataFrame(data)
display(df)
# Out:
#   Empleado Departamento  Salario  Experiencia
# 0     Juan       Ventas    50000            5
# 1      Ana    Marketing    60000            7
# 2    Pedro       Ventas    55000            6
# 3     Luis           IT    58000            8
# 4    Maria    Marketing    62000            9

# %%
#agrupar por depatamentos
salarios_por_departamento = df.groupby('Departamento')['Salario'].sum()
salarios_por_departamento
# Out:
# Departamento
# IT            58000
# Marketing    122000
# Ventas       105000
# Name: Salario, dtype: int64

# %%
plt.figure(figsize=(10,6))
salarios_por_departamento.plot(kind='bar', color='lightgreen')
plt.xlabel('Departamento')
plt.ylabel('Suma de salarios')
plt.title('Suma de Salarios por Departamento')
plt.show()

# %%
#libreria para graficar seaborn
#estilo visual distinto a mathplotlib
plt.figure(figsize=(10,6))
sns.boxplot(x='Departamento',y='Salario',data=df)
plt.title('Distribucion de salarios por Departamento')
plt.show()
